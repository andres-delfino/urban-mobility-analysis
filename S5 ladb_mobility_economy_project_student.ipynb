# %% [markdown]
# # ¡Hola Necrorevan! 😊
#
# Mi nombre es **Alejandro Castellanos** y hoy tengo el placer de ser el revisor de tu proyecto.
#
# Voy a revisar todo tu código con detalle, buscando tanto los puntos fuertes como aquellos en los que podrías mejorar. Te dejaré comentarios a lo largo del notebook, destacando lo que has hecho bien y sugiriendo ajustes donde sea necesario. Si encuentro algún error, no te preocupes, te lo haré saber de forma clara y te daré información útil para que puedas corregirlo en la próxima iteración. Si en algún punto tienes comentarios, siéntete libre de dejarlos también.
#
#
# Encontrarás mis comentarios específicos dentro de cajas verdes, amarillas o rojas, es muy importante que no muevas, modifiques o borres mis comentarios, con el fin de tener un seguimiento adecuado de tu proceso:
#
#
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class=“tocSkip”></a>
# Si todo está perfecto.
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor</b> <a class=“tocSkip”></a>
# Si tu código está bien pero se puede mejorar o hay algún detalle que le hace falta.
# </div>
#
# <div class="alert alert-block alert-danger">
# <b>Comentario del revisor</b> <a class=“tocSkip”></a>
# Si de pronto hace falta algo o existe algún problema con tu código o conclusiones.
# </div>
#
# Puedes responderme de esta forma:
# <div class="alert alert-block alert-info">
# <b>Respuesta del estudiante</b> <a class=“tocSkip”></a>
# </div>
#
# A continuación te dejaré un comentario general con mi valoración del proyecto. **¡Mi objetivo es que sigas aprendiendo y mejorando con cada paso!**

# %% [markdown]
# ----

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Comentario General del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# Necrorevan, hiciste un buen trabajo en la carga, exploración inicial y organización general del proyecto, porque desde el inicio se nota una lectura adecuada de los datasets, una revisión útil de su estructura y una integración bien encaminada para construir la tabla final, además de que los gráficos y el resumen permiten seguir la idea principal del análisis.
#
#
# No obstante, conviene pulir algunos detalles de limpieza y validación, especialmente en la estandarización de nombres de columnas y en comprobaciones breves después de filtrar, graficar y exportar, pero sobre todo es importante corregir las columnas que aún quedaron como texto, como *population_m* y *pm2.5_(μg/m³)*, ya que eso termina afectando también variables derivadas como *population* y puede comprometer la calidad del dataset final y de las conclusiones. También revisa que la agregación se haga sobre el subconjunto filtrado de 2024 y no sobre todo **traffic**, para que el análisis responda exactamente al objetivo planteado y evite ruido innecesario.
#
# ¡No te preocupes! Cada ajuste que haces es una oportunidad para aprender y mejorar. Vas por buen camino, y estoy seguro de que en la siguiente versión harás un gran trabajo y lograrás completar el proyecto con éxito. ¡Sigue adelante!
#
#
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario General del revisor (2da Iteración)</b> <a class=“tocSkip”></a>
#
# ¡Necrorevan excelente trabajo con los ajustes! Tu proyecto ahora cumple con todos los objetivos propuestos. Estoy seguro de que lo que aprendiste aquí te será muy útil más adelante.
#
# ¡Éxito en tu próximo sprint! 🚀
#
# *Estado del Proyecto:* **Aprobado**
#
# </div>

# %% [markdown]
# -----

# %% [markdown]
# ## Introducción
#
# Como analista de datos, tu objetivo es **evaluar cómo la movilidad urbana se relaciona con la productividad económica en las principales ciudades latinoamericanas**.
# Para ello trabajarás con datos reales de TomTom Traffic Index y OECD Cities, que deberás limpiar, combinar y analizar para identificar en qué ciudades conviene invertir en infraestructura de transporte.

# %% [markdown]
# ## 🧩 Paso 1: Cargar y explorar
#
# Antes de limpiar o combinar los datos, es necesario **familiarizarte con la estructura de ambos datasets**.
# En esta etapa, validarás que los archivos se carguen correctamente, conocerás sus columnas y tipos de datos, y detectarás posibles inconsistencias.
#
# ### 1.1 Carga de datos y vista rápida
#
# **🎯Objetivo:**
# Importar las librerías necesarias, cargar los archivos CSV en DataFrames y realizar una revisión preliminar para entender su contenido.
#
# **Instrucciones:**
# - Importa las librerías `pandas`, `numpy`, `seaborn` y `matplotlib.pyplot`.
# - Carga los archivos usando `pd.read_csv()`:
#   - `'/datasets/tomtom_traffic.csv'`
#   - `/datasets/oecd_city_economy.csv` `.
# - Guarda los DataFrames en las variables `traffic` y `eco`.
# - Muestra las primeras 5 filas de cada DataFrame.

# %%
# importar librerías
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# cargar archivos
traffic = pd.read_csv('/datasets/tomtom_traffic.csv')
eco = pd.read_csv('/datasets/oecd_city_economy.csv') #completa el código

# %%
traffic.head()# mostrar las primeras 5 filas de traffic
# Out:
#   Country       City            UpdateTimeUTC  JamsDelay  TrafficIndexLive  \
# 0     ARE  abu-dhabi  2025-01-13 04:01:30.001      650.7              36.0
# 1     ARE  abu-dhabi  2025-01-13 03:46:00.000      540.4              30.0
# 2     ARE  abu-dhabi  2025-01-13 02:46:30.000       71.8               7.0
# 3     ARE  abu-dhabi  2025-01-13 01:46:30.001        8.2               2.0
# 4     ARE  abu-dhabi  2025-01-13 00:01:30.000        1.1               1.0
#
#    JamsLengthInKms  JamsCount  TrafficIndexWeekAgo     UpdateTimeUTCWeekAgo  \
# 0            109.1      162.0                 30.0  2025-01-06 04:01:30.000
# 1            101.4      136.0                 27.0  2025-01-06 03:46:30.001
# 2             18.9       23.0                  6.0  2025-01-06 02:46:30.000
# 3              4.1        2.0                  2.0  2025-01-06 01:46:30.000
# 4              0.2        1.0                  1.0  2025-01-06 00:01:30.000
#
#    TravelTimeLivePer10KmsMins  TravelTimeHistoricPer10KmsMins  MinsDelay
# 0                   11.614767                       10.265330   1.349437
# 1                   11.003180                       10.031544   0.971635
# 2                    8.196278                        8.196510  -0.000232
# 3                    7.723808                        7.899046  -0.175238
# 4                    8.336363                        8.604379  -0.268016

# %%
eco.head(5) # mostrar las primeras 5 filas de eco
# Out:
#    Year            City    Country City GDP/capita Unemployment %  \
# 0  2023    buenos-aires  Argentina       15.782,00           6.2%
# 1  2023       sao-paulo     Brazil       14.475,00           9.1%
# 2  2023  rio-de-janeiro     Brazil       13.142,00           9.8%
# 3  2023        brasilia     Brazil       15.999,00           8.3%
# 4  2023        salvador     Brazil        8.761,00          13.1%
#
#   PM2.5 (μg/m³) Population (M)
# 0          15,2          15,30
# 1         29,50          22,50
# 2         19,10          13,60
# 3         13,50           4,70
# 4         16,00           3,90

# %% [markdown]
# **Tip:** Si no usas `print()` la tabla se vera mejor.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (1ra Iteración)</b> <a class="tocSkip"></a>
#
# Cargaste correctamente las librerías clave y leíste **traffic** y **eco** con `read_csv`, mostrando una vista rápida con `.head()` que permite entender la forma de ambas tablas desde el inicio.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# Ten en cuenta que la función `head` ya muestra por defecto las primera 5 filas de los datasets, por lo que no es necesario definir el parámetro 5 dentro de esta función.
#
# </div>

# %% [markdown]
# ---
#
# ## 🧩Paso 2: Explorar, limpiar y preparar los datos
#
# Antes de combinar los datasets, inspecciona su estructura, tipos de datos, columnas y valores faltantes.
# Anota las columnas que necesiten limpieza y luego estandariza los nombres de columnas.
#
# ### 2.1 Explorar la estructura y tipos de datos
#
# **🎯Objetivo:**
# Identificar columnas con tipos incorrectos, distribución y nulos, anotar las columnas que requieren conversión.
#
# **Instrucciones:**
#
# - Usa `.info()` para conocer la estructura de ambos DataFrames.
# - Muestra los primeros 3 renglones de cada DF.
# - Identifica si los detalles de cada DF estan bien o si requieren correcciones y escribe tus conclusiones en el bloque Markdown.
#   - ¿Hay columnas que requieren conversión?¿ Cuáles son? ¿Que tipo de dato ienen y cuál deberían de tener?
#   - ¿Hay datos ausentes en alguna columna?

# %%
traffic.info()# Examinar la estructura de traffic
traffic.head(3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1004464 entries, 0 to 1004463
# Data columns (total 12 columns):
#  #   Column                          Non-Null Count    Dtype
# ---  ------                          --------------    -----
#  0   Country                         1004464 non-null  object
#  1   City                            1004464 non-null  object
#  2   UpdateTimeUTC                   1004464 non-null  object
#  3   JamsDelay                       1004464 non-null  float64
#  4   TrafficIndexLive                1004464 non-null  float64
#  5   JamsLengthInKms                 1004464 non-null  float64
#  6   JamsCount                       1004464 non-null  float64
#  7   TrafficIndexWeekAgo             1004464 non-null  float64
#  8   UpdateTimeUTCWeekAgo            1004464 non-null  object
#  9   TravelTimeLivePer10KmsMins      1004464 non-null  float64
#  10  TravelTimeHistoricPer10KmsMins  1004464 non-null  float64
#  11  MinsDelay                       1004464 non-null  float64
# dtypes: float64(8), object(4)
# memory usage: 92.0+ MB
#   Country       City            UpdateTimeUTC  JamsDelay  TrafficIndexLive  \
# 0     ARE  abu-dhabi  2025-01-13 04:01:30.001      650.7              36.0
# 1     ARE  abu-dhabi  2025-01-13 03:46:00.000      540.4              30.0
# 2     ARE  abu-dhabi  2025-01-13 02:46:30.000       71.8               7.0
#
#    JamsLengthInKms  JamsCount  TrafficIndexWeekAgo     UpdateTimeUTCWeekAgo  \
# 0            109.1      162.0                 30.0  2025-01-06 04:01:30.000
# 1            101.4      136.0                 27.0  2025-01-06 03:46:30.001
# 2             18.9       23.0                  6.0  2025-01-06 02:46:30.000
#
#    TravelTimeLivePer10KmsMins  TravelTimeHistoricPer10KmsMins  MinsDelay
# 0                   11.614767                       10.265330   1.349437
# 1                   11.003180                       10.031544   0.971635
# 2                    8.196278                        8.196510  -0.000232

# %% [markdown]
# En la estructura del DF traffic, se observa que:
# - Las columnas `UpdateTimeUTC` y `UpdateTimeUTCWeekAgo` son de tipo object y necesitan ser convertidas a columnas con tipo de dato datetime
# - Las columnas `Country` y `City` son de tipo object y la descripcion del proyecto indica que son string, pero para propositos de este proyecto no se considera o no se solicita la conversion y una consulta con Dot indica que no es necesario en este caso en especifico
# - Lo mismo ocurre con la columna `JamsCount` (siendo float, deberia ser integer). Por el momento la dejaremos como esta, ya que es posible que esta columna no sea necesaria para el analisis
# - La muestra de 3 renglones indica un numero negativo en MinsDelay en el 3er renglon.  Por el momento la dejaremos como esta, ya que es posible que esta columna no sea necesaria para el analisis

# %%
eco.info()
eco.head(3)# Examinar la estructura de eco
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Year             30 non-null     int64
#  1   City             30 non-null     object
#  2   Country          30 non-null     object
#  3   City GDP/capita  30 non-null     object
#  4   Unemployment %   30 non-null     object
#  5   PM2.5 (μg/m³)    30 non-null     object
#  6   Population (M)   30 non-null     object
# dtypes: int64(1), object(6)
# memory usage: 1.8+ KB
#    Year            City    Country City GDP/capita Unemployment %  \
# 0  2023    buenos-aires  Argentina       15.782,00           6.2%
# 1  2023       sao-paulo     Brazil       14.475,00           9.1%
# 2  2023  rio-de-janeiro     Brazil       13.142,00           9.8%
#
#   PM2.5 (μg/m³) Population (M)
# 0          15,2          15,30
# 1         29,50          22,50
# 2         19,10          13,60

# %% [markdown]
# En la estructura del DF eco, se observa que:
# - Las columnas `City GDP/capita`, `Unemployment %` y`Population M` son del tipo object y necesitan ser convertidas a float.
# - Lo mismo ocurre con la columna `PM2.5 (μg/m³)`, pero como es poco probable que vayamos a usar esta columna en el análisis, vamos a dejarla como está. Igual haremos con `City` y `Country`, las cuales aunque deberian ser string, funcionaran igualmente bien como object para propositos de este proyecto.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (1ra Iteración)</b> <a class="tocSkip"></a>
#
# Revisaste bien la estructura con `.info()` y una muestra de filas, lo que ayuda a detectar de inmediato columnas en `object` y anticipar qué campos requieren conversión antes del análisis.
#
# </div>

# %% [markdown]
# ### 2.2 Renombrar columnas
#
# **🎯Objetivo:**
# Estandarizar los nombres de columnas para evitar errores y facilitar la unión de los datasets.
#
# **Instrucciones:**
#
# - Cambia los nombres de las columnas para que tengan el formato `snake_case`.
#     - `Country` → `country`
#     - `UpdateTimeUTC` → `update_time_utc`
# - Verifica que los cambios se hayan aplicado correctamente usando `.columns`.

# %%
# Estandarizar los nombres de las columnas de traffic
#tu código aquí


traffic.columns = ["country", "city", "update_time_utc", "jamsdelay", "trafficindexlive", "jamslengthinkms", "jamscount", "trafficindexweekago", "updatetimeutcweekago", "traveltimeliveper10kmsmins",
       "traveltimehistoricper10kmsmins", "minsdelay"]


 


# verificar cambios
traffic.columns
# Out:
# Index(['country', 'city', 'update_time_utc', 'jamsdelay', 'trafficindexlive',
#        'jamslengthinkms', 'jamscount', 'trafficindexweekago',
#        'updatetimeutcweekago', 'traveltimeliveper10kmsmins',
#        'traveltimehistoricper10kmsmins', 'minsdelay'],
#       dtype='object')

# %%
# Estandarizar los nombres de las columnas de eco
#tu código aquí
eco.columns = ["year", "city", "country", "city_gdp_capita", "unemployment_pct",
       "pm2_5", "population_m"]

eco = eco.drop(columns=['city_gdp/capita_dup'], errors='ignore')


# verificar cambios
eco.columns
# Out:
# Index(['year', 'city', 'country', 'city_gdp_capita', 'unemployment_pct',
#        'pm2_5', 'population_m'],
#       dtype='object')

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor (1ra Iteración)</b> <a class="tocSkip"></a>
#
# Aplicaste una estandarización inicial en **traffic** y **eco**, pero quedaron nombres con caracteres especiales y separadores como *city_gdp/capita* y *pm2.5_(μg/m³)*, lo que suele volver más frágil la manipulación y la lectura del dataset.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (2da Iteración)</b> <a class=“tocSkip”></a>
#
# Buen trabajo ajustando los nombres
#
# </div>

# %% [markdown]
# ### 2.3 Corregir formatos numéricos y de fecha
#
# **🎯Objetivo:**
# Asegurar que las columnas de fechas y valores numéricos estén en formatos correctos para permitir análisis, cálculos y comparaciones precisas.
#
# **Instrucciones:**
#
# - Convierte las columnas de fecha de `traffic` a formato `datetime`. Haz el cambio a prueba de errores.
# - En el dataset `eco`, limpia los valores numéricos:
#     - En `city_gdp_capita`: elimina separadores de miles (`.`) y reemplaza las comas (`','`) por puntos (`'.'`) antes de convertir a tipo `float`.
#     - En `unemployment_pct`: elimina el símbolo de porcentaje (`%`) y reemplaza las comas (`','`) por puntos (`'.'`) antes de convertir a tipo `float`.
#     - En `population_m`: reemplaza las comas (`','`) por puntos (`'.'`) antes de convertir a tipo `float`.
# - Finalmente, crea una nueva columna llamada `population` multiplicando `population_m` por 1,000,000 para obtener la población total.

# %% [markdown]
# <details>
# <summary>Haz clic para ver la pista</summary>
# para eliminar símbolos, puedes reemplazarlos por un texto vacío.

# %%
# Convertir las columnas de traffic a tipo fecha con pd.to_datetime()
traffic['update_time_utc'] = pd.to_datetime(traffic["update_time_utc"], errors="coerce") #tu código aquí
traffic['updatetimeutcweekago'] =  pd.to_datetime(traffic["updatetimeutcweekago"], errors="coerce")#tu código aquí


# verificar el cambio
traffic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1004464 entries, 0 to 1004463
# Data columns (total 12 columns):
#  #   Column                          Non-Null Count    Dtype
# ---  ------                          --------------    -----
#  0   country                         1004464 non-null  object
#  1   city                            1004464 non-null  object
#  2   update_time_utc                 1004464 non-null  datetime64[ns]
#  3   jamsdelay                       1004464 non-null  float64
#  4   trafficindexlive                1004464 non-null  float64
#  5   jamslengthinkms                 1004464 non-null  float64
#  6   jamscount                       1004464 non-null  float64
#  7   trafficindexweekago             1004464 non-null  float64
#  8   updatetimeutcweekago            1004464 non-null  datetime64[ns]
#  9   traveltimeliveper10kmsmins      1004464 non-null  float64
#  10  traveltimehistoricper10kmsmins  1004464 non-null  float64
#  11  minsdelay                       1004464 non-null  float64
# dtypes: datetime64[ns](2), float64(8), object(2)
# memory usage: 92.0+ MB

# %%
# Limpia separadores y convierte columnas numéricas en eco
eco['city_gdp_capita'] = eco['city_gdp_capita'].astype(str).str.replace('.', '').str.replace(',', '.').astype(float)
eco['pm2_5'] = eco['pm2_5'].astype(str).str.replace(',', '.').astype(float)
eco['unemployment_pct'] = eco['unemployment_pct'].astype(str).str.replace('%', '').str.replace(',', '.').astype(float)
eco['population_m'] = eco['population_m'].astype(str).str.replace(',', '.').astype(float)

# Calcula la población total en unidades absolutas (Multiplica * 1000000)
eco['population'] = eco['population_m']*1000000

# verificar el cambio
eco.info()
eco.head(3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   year              30 non-null     int64
#  1   city              30 non-null     object
#  2   country           30 non-null     object
#  3   city_gdp_capita   30 non-null     float64
#  4   unemployment_pct  30 non-null     float64
#  5   pm2_5             30 non-null     float64
#  6   population_m      30 non-null     float64
#  7   population        30 non-null     float64
# dtypes: float64(5), int64(1), object(2)
# memory usage: 2.0+ KB
#    year            city    country  city_gdp_capita  unemployment_pct  pm2_5  \
# 0  2023    buenos-aires  Argentina          15782.0               6.2   15.2
# 1  2023       sao-paulo     Brazil          14475.0               9.1   29.5
# 2  2023  rio-de-janeiro     Brazil          13142.0               9.8   19.1
#
#    population_m  population
# 0          15.3  15300000.0
# 1          22.5  22500000.0
# 2          13.6  13600000.0

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Comentario del revisor (1ra Iteración)</b> <a class="tocSkip"></a>
#
# Convertiste bien *update_time_utc* en **traffic** y limpiaste *unemployment_pct* y *city_gdp/capita* en **eco**, pero *population_m* y *pm2.5_(μg/m³)* se mantienen como `object` (recuerda que el separador decimal debe ser punto `(.)`) y por eso *population* también queda como texto, afectando la calidad del dataset final.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (2da Iteración)</b> <a class=“tocSkip”></a>
#
# Perfecto, ahora la información es consistente con el tipo de datos
#
# </div>

# %% [markdown]
# ---
#
# ## 🧩Paso 3: Extraer año y filtrar
#
# Extraer el año permite filtrar la información y trabajar solo con el período más reciente y relevante.
#
# ### 3.1 Extraer columna año y filtrar 2024
#
# **🎯Objetivo**
# Identificar el año de cada registro y mantener solo los registros del 2024.
#
# **Intrucciones**
#
# - Como el DataFrame `traffic` no tiene una columna de año, utiliza el atributo `.dt.year` sobre su columna de fecha para crear una nueva columna llamada `year`.
# - Filtra las filas donde el año sea **2024**.
# - Utiliza `.copy()` para crear dos nuevos DataFrames (`traffic_2024` y `eco_2024`) para evitar modificar el dataset original.

# %%
# Extraer el año de las fechas en update_time_utc
traffic['year'] = traffic["update_time_utc"].dt.year

# Verificar cambio
traffic.head(3)
# Out:
#   country       city         update_time_utc  jamsdelay  trafficindexlive  \
# 0     ARE  abu-dhabi 2025-01-13 04:01:30.001      650.7              36.0
# 1     ARE  abu-dhabi 2025-01-13 03:46:00.000      540.4              30.0
# 2     ARE  abu-dhabi 2025-01-13 02:46:30.000       71.8               7.0
#
#    jamslengthinkms  jamscount  trafficindexweekago    updatetimeutcweekago  \
# 0            109.1      162.0                 30.0 2025-01-06 04:01:30.000
# 1            101.4      136.0                 27.0 2025-01-06 03:46:30.001
# 2             18.9       23.0                  6.0 2025-01-06 02:46:30.000
#
#    traveltimeliveper10kmsmins  traveltimehistoricper10kmsmins  minsdelay  year
# 0                   11.614767                       10.265330   1.349437  2025
# 1                   11.003180                       10.031544   0.971635  2025
# 2                    8.196278                        8.196510  -0.000232  2025

# %%
# Filtra los registros del año 2024
traffic_2024 = traffic[traffic["year"] == 2024].copy()    
eco_2024 = eco[eco["year"] == 2024].copy() 


# Revisar dataframes nuevos
display(traffic_2024.head())
display(eco_2024.head())

# Verificacion de filtrado exitoso
print(f"Años únicos en traffic_2024: {traffic_2024['year'].unique()}")
print(f"Años únicos en eco_2024: {eco_2024['year'].unique()}")
print(f"Tamaño original traffic: {len(traffic)}, después del filtro: {len(traffic_2024)}")
print(f"Tamaño original eco: {len(eco)}, después del filtro: {len(eco_2024)}")
# Out:
#     country       city         update_time_utc  jamsdelay  trafficindexlive  \
# 302     ARE  abu-dhabi 2024-12-31 23:01:30.000       12.9               5.0
# 303     ARE  abu-dhabi 2024-12-31 22:01:30.000      136.0              21.0
# 304     ARE  abu-dhabi 2024-12-31 21:16:30.000      455.2              31.0
# 305     ARE  abu-dhabi 2024-12-31 20:01:00.001      399.4              27.0
# 306     ARE  abu-dhabi 2024-12-31 19:46:00.000      366.4              28.0
#
#      jamslengthinkms  jamscount  trafficindexweekago    updatetimeutcweekago  \
# 302              2.5        5.0                  2.0 2024-12-24 23:01:30.001
# 303             20.6       32.0                  3.0 2024-12-24 22:01:30.000
# 304             40.4       72.0                  4.0 2024-12-24 21:01:30.000
# 305             38.0       75.0                  6.0 2024-12-24 20:01:30.001
# 306             39.8       82.0                  9.0 2024-12-24 19:01:00.000
#
#      traveltimeliveper10kmsmins  traveltimehistoricper10kmsmins  minsdelay  \
# 302                    8.560399                        8.519634   0.040765
# 303                   10.355732                        9.049445   1.306286
# 304                   11.456878                        9.305174   2.151704
# 305                   11.670062                        9.952811   1.717252
# 306                   11.686322                       10.008469   1.677853
#
#      year
# 302  2024
# 303  2024
# 304  2024
# 305  2024
# 306  2024
#     year            city    country  city_gdp_capita  unemployment_pct  pm2_5  \
# 15  2024    buenos-aires  Argentina          18117.0               7.2   14.5
# 16  2024       sao-paulo     Brazil          14703.0               8.5   28.0
# 17  2024  rio-de-janeiro     Brazil          13349.0               9.2   18.4
# 18  2024        brasilia     Brazil          16251.0               7.8   12.8
# 19  2024        salvador     Brazil           8899.0              12.4   15.2
#
#     population_m  population
# 15          15.4  15400000.0
# 16          22.6  22600000.0
# 17          13.7  13700000.0
# 18           4.8   4800000.0
# 19           3.9   3900000.0
# Años únicos en traffic_2024: [2024]
# Años únicos en eco_2024: [2024]
# Tamaño original traffic: 1004464, después del filtro: 886779
# Tamaño original eco: 30, después del filtro: 15

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor (1ra Iteración)</b> <a class="tocSkip"></a>
#
# La extracción de *year* desde *update_time_utc* y el filtrado a 2024 en **traffic_2024** y **eco_2024** están bien planteados y usaste `.copy()`, aunque faltó una verificación corta de años únicos o tamaños para confirmar el filtrado.
#
# </div>

# %% [markdown]
# ---
#
# ## 🧩Paso 4: Analizar y resumir datos de movilidad
#
# Como el dataset de tráfico contiene **múltiples registros por ciudad**. En esta parte, calcularás los promedios anuales por ciudad para simplificar el análisis y obtener una visión más clara de las tendencias generales.
#
# ### 4.1 Calcular promedios de tráfico por ciudad
#
# **🎯Objetivo:**
# Obtener una vista consolidada del tráfico promedio por ciudad y año, para analizar patrones generales sin depender de datos diarios.
#
# **Instrucciones**
#
# - Agrupa los datos por `city`, `country` y `year`.
# - Calcula el promedio **solo de las métricas de tráfico más relevantes**: como `jams_delay`, `traffic_index_live`, `jams_length_kms`, `jams_count`, `mins_delay`, y tiempos de viaje (`travel_time_live_per_10kms_mins` y `travel_time_hist_per_10kms_mins`).
# - Guarda el resultado como `traffic_city_year_2024`, mantén las columnas como variables (no índices).

# %% [markdown]
# <details>
# <summary>Haz clic para ver la pista</summary>
# Usa ".agg()" para aplicar funciones de promedio. Al final, reinicia el índice para mantener las columnas de la agrupación como variables (no índices).

# %%
# Calcular los  promedios de trafico por ciudad, país y año

traffic_city_year_2024 = traffic_2024.groupby(['city', 'country', 'year']).agg({
    'jamsdelay': 'mean',  # Sin lista, solo 'mean'
    'trafficindexlive': 'mean',
    'jamscount': 'mean',
    'minsdelay': 'mean',
    'traveltimeliveper10kmsmins': 'mean',
    'traveltimehistoricper10kmsmins': 'mean'
}).reset_index()




# Mostrar resultado
traffic_city_year_2024.head()
# Out:
#         city country  year   jamsdelay  trafficindexlive  jamscount  \
# 0   a-coruna     ESP  2024   17.935187         15.259774   4.934405
# 1     aachen     DEU  2024   26.732141         20.960314   6.601832
# 2     aarhus     DNK  2024   21.200616         16.575891   6.109987
# 3  abu-dhabi     ARE  2024  171.157315         13.902028  47.268019
# 4      adana     TUR  2024   83.864761         22.541040  23.754620
#
#    minsdelay  traveltimeliveper10kmsmins  traveltimehistoricper10kmsmins
# 0   0.774172                   16.267977                       15.493804
# 1   0.792968                   13.397861                       12.604894
# 2   0.495276                   15.219292                       14.724016
# 3   0.139764                    9.829092                        9.689328
# 4   1.129749                   15.879694                       14.749945

# %% [markdown]
# ### 🧠 **Momento de reflexión**
#
# ¡Excelente trabajo hasta aquí!
#
# Ahora que ya tienes los promedios anuales por ciudad, es momento de **observarlos** con atención.
#
# Piensa:
#
# - ¿Cuál crees que tiene el mayor tiempo promedio de tráfico?
# - ¿Será una ciudad de **Europa**, de **Latinoamérica** o de **otra región** del mundo?
#
# Para descubrirlo, ejecuta esta línea de código:
#
# `traffic_city_year_2024.sort_values(["jams_delay"], ascending=False)`
#
#
# 🔍 Observa qué ciudad aparece en los primeros lugares.
#
# ¿Te sorprenden los resultados? , ¿Coinciden con lo que imaginabas?

# %%
traffic_city_year_2024.sort_values(["jamsdelay"], ascending=False)
# Out:
#             city country  year    jamsdelay  trafficindexlive   jamscount  \
# 221  mexico-city     MEX  2024  2833.057892         34.218190  594.969392
# 352        tokyo     JPN  2024  2152.574357         36.805059  518.809420
# 246     new-york     USA  2024  2133.400000         28.210388  544.474902
# 200       london     GBR  2024  2050.703662         29.230166  471.795554
# 211       manila     PHL  2024  1741.493381         66.129402  341.881205
# ..           ...     ...   ...          ...               ...         ...
# 111      dunedin     NZL  2024     4.651175         15.430809    1.591384
# 363      uppsala     SWE  2024     4.194486         13.939168    1.349672
# 123     fujairah     ARE  2024     4.025959         10.907719    1.373006
# 12        almere     NLD  2024     3.633523          6.290478    1.064063
# 117      el-paso     USA  2024     0.299024          2.340435    0.078118
#
#      minsdelay  traveltimeliveper10kmsmins  traveltimehistoricper10kmsmins
# 221   1.855542                   21.809092                       19.953550
# 352   0.698152                   22.443778                       21.745626
# 246   1.396351                   18.505043                       17.108691
# 200   1.325160                   17.714139                       16.388979
# 211   2.469894                   27.134629                       24.664734
# ..         ...                         ...                             ...
# 111   0.633294                   16.226009                       15.592715
# 363   0.501802                   15.746717                       15.244916
# 123   0.194951                   11.662590                       11.467639
# 12   -0.017544                    9.467150                        9.484694
# 117  -0.250676                   10.690269                       10.940945
#
# [387 rows x 9 columns]

# %% [markdown]
# La ciudad con el mayor tiempo promedio de tráfico es Mexico City

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Comentario del revisor (1ra Iteración)</b> <a class="tocSkip"></a>
#
# La agregación por *city*, *country* y *year* está bien construida y los promedios calculados son coherentes, pero el `groupby` se hace sobre **traffic** completo en vez de **traffic_2024**, lo que añade ruido y trabajo innecesario para el objetivo anual.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# Buen trabajo con los ajustes
#
# </div>

# %% [markdown]
# ---
#
# ## 🧩Paso 5: Unir movilidad y economía
#
# Combinar datasets te permite analizar cómo se relacionan los indicadores económicos con los de movilidad.
#
# ### 5.1 Unir tráfico (tabla principal) con indicadores económicos
#
# **🎯Objetivo:**
# Combinar la información de tráfico y economía en un solo DataFrame para analizar cómo las condiciones económicas se relacionan con la movilidad urbana.
#
# **Instrucciones**
# - Selecciona solo las **columnas relevantes** de cada dataset (por ejemplo, variables clave de tráfico y de economía).
# - Usa `.copy()` al crear subconjuntos para evitar modificar el dataset original.
# - Une ambos DataFrames y define como **claves de unión** a `city` y `year`.
# - Mantén solo las ciudades y años presentes en ambos datasets.
# - Guarda el resultado en una nueva variable llamada `merged` y muestra las primeras 5 filas.

# %% [markdown]
# <details>
# <summary>Haz clic para ver la pista</summary>
# Aplica una unión de tipo "inner" para mantener las ciudades y años presentes en ambos datasets.

# %%
# Seleccionar columnas clave de tráfico y economía
left_cols = ['city','country','year','jamsdelay','trafficindexlive','jamscount','minsdelay',
             'traveltimeliveper10kmsmins','traveltimehistoricper10kmsmins']

right_cols = ['city','year','city_gdp_capita','unemployment_pct','pm2_5','population']


# Usar .copy() para crear los dos nuevos datasets reducidos
traffic_2024_small = traffic_city_year_2024[left_cols].copy()
eco_2024_small = eco_2024[right_cols].copy()

traffic_2024_small = traffic_2024_small.reset_index(drop=True)
eco_2024_small = eco_2024_small.reset_index(drop=True)

# Unir datasets
merged = pd.merge(traffic_2024_small, eco_2024_small, on=['city', 'year'], how='inner')# tu código aquí

# Mostrar las primeras 5 filas
merged.head()# tu código aquí
# Out:
#              city country  year    jamsdelay  trafficindexlive   jamscount  \
# 0  belo-horizonte     BRA  2024   263.047879         19.428946   68.805422
# 1          bogota     COL  2024  1141.552364         37.614273  230.566550
# 2        brasilia     BRA  2024   101.576326         11.258220   27.280140
# 3    buenos-aires     ARG  2024   571.089593         17.756012  137.359860
# 4        curitiba     BRA  2024   183.469274         14.954545   46.898164
#
#    minsdelay  traveltimeliveper10kmsmins  traveltimehistoricper10kmsmins  \
# 0   0.487228                   18.304538                       17.817311
# 1   1.699628                   24.992185                       23.292557
# 2   0.193442                   13.338658                       13.145216
# 3   0.416566                   17.907916                       17.491349
# 4   0.139965                   17.258700                       17.118736
#
#    city_gdp_capita  unemployment_pct  pm2_5  population
# 0          11124.0               9.5   16.8   6100000.0
# 1          11442.0              10.0   17.6  11300000.0
# 2          16251.0               7.8   12.8   4800000.0
# 3          18117.0               7.2   14.5  15400000.0
# 4          12381.0               8.2   13.5   3700000.0

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (1ra Iteración)</b> <a class="tocSkip"></a>
#
# Seleccionaste columnas relevantes y la unión `inner` por *city* y *year* funciona para integrar **traffic_2024_small** con **eco_2024_small**.
# </div>

# %% [markdown]
# ---
#
# ## 🧩Paso 6: Visualización y análisis de relaciones
#
# Ahora que tienes un dataset limpio y unificado, es momento de **visualizar patrones**.
# Los gráficos te ayudarán a entender cómo se relacionan las variables económicas con las de movilidad urbana.
#
# ### 6.1 Visualizar relaciones entre economía y tráfico
#
# **🎯Objetivo:**
# Analizar visualmente la distribución y la relación entre indicadores de tráfico y economía en 2024, para identificar posibles patrones o tendencias generales entre ambas variables.
#
# **Instrucciones**
# - Usa las librerías `seaborn` y `matplotlib.pyplot` para generar los gráficos.
# - Visualiza la distribución del **tráfico** (`jams_delay`) mediante:
#     - **Boxplot** → para observar la media, mediana y detectar valores atípicos.
# - Visualiza la distribución de la **economía** (`city_gdp_capita`) mediante:
#     - **Histograma** → para analizar la forma de la distribución y el valor promedio del PIB per cápita.
# - Finalmente, **compara ambas variables**, para observar si existe alguna relación entre ellas, haciendo un solo gráfico de barras donde aparezcan ambos indicadores.
# - Recuerda agregar título y etiquetas a los ejes de tus gráficos.
# - Observa y comenta los patrones, valores extremos o posibles relaciones que identifiques.

# %% [markdown]
# **Tip:** Dentro de los parentesis del boxplot, agrega `showmeans=True` para ver la media en el gráfico.

# %%
# Crear boxplot para observar el comportamiento de los minutos de congestion JamsDelay
# crea tu gráfico

plt.figure(figsize=(10, 4))
sns.boxplot(data=merged, x='jamsdelay', showmeans=True)

mean_value = merged['jamsdelay'].mean()
plt.title(f'Distribución de Retrasos por Congestión (2024)\nPromedio: {mean_value:.2f} minutos')

# Agregar etiquetas claras y profesionales
plt.xlabel('Retrasos por Congestión (minutos)')
plt.ylabel('Frecuencia')

plt.show()

# %%
# Crear histograma para ver la distribución de la economía (city_gdp_capita)

merged['city_gdp_capita'].hist(bins=15, figsize=(10, 5))
plt.title('Distribución del PIB per cápita en ciudades latinoamericanas (2024)')
plt.xlabel('PIB per cápita (USD)')
plt.ylabel('Número de ciudades')
plt.show()

# %%
# Gráfico de barras para comparar jams_delay y city_gdp_capita por ciudad
#merged.plot( ... , y=['jams_delay', 'city_gdp_capita'])

# Gráfico combinado con barras agrupadas y dos ejes Y
fig, ax1 = plt.subplots(figsize=(12, 6))

# Configurar posiciones para barras agrupadas
x = np.arange(len(merged['city']))
width = 0.35  # ancho de las barras

# Eje izquierdo (primario) - Congestión
color1 = 'tab:red'
ax1.set_xlabel('Ciudades')
ax1.set_ylabel('Minutos de congestión', color=color1)
bars1 = ax1.bar(x - width/2, merged['jamsdelay'], width, 
                color=color1, alpha=0.7, label='Congestión')
ax1.tick_params(axis='y', labelcolor=color1)

# Eje derecho (secundario) - PIB per cápita
ax2 = ax1.twinx()
color2 = 'tab:blue'
ax2.set_ylabel('PIB per cápita (USD)', color=color2)
bars2 = ax2.bar(x + width/2, merged['city_gdp_capita'], width,
                color=color2, alpha=0.7, label='PIB per cápita')
ax2.tick_params(axis='y', labelcolor=color2)

# Configurar etiquetas del eje X
ax1.set_xticks(x)
ax1.set_xticklabels(merged['city'], rotation=45)

# Título y leyenda
plt.title('Congestión vs PIB per Cápita por Ciudad')
lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines1 + lines2, labels1 + labels2, loc='upper left')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Tip:** Antes del `plt.show()` agrega el código `plt.xticks(rotation=90)` para rotar las etiquetas del eje X en 90 grados.

# %% [markdown]
# ### 🧠 **Reflexiona**
# Excelente trabajo llegando a esta etapa del análisis. Antes de avanzar, revisa tus gráficos, tómate un momento para pensar:
#
# * ¿Las ciudades con mayor PIB per cápita también presentan más congestión?
#
# * ¿O sucede lo contrario, o no existe una relación clara?

# %% [markdown]
# Escribe tus comentarios: No existe una relacion clara. Montevideo tiene tiene el mayor PIB per capita y sin embargo su congestion es de las mas bajas. Porto Alegre y Recife tienen practicamente el mismo nivel de congestion y a pesar de ello Porto alegre tiene mayor PIB. Lima y Rio de Janeeiro tienen un PIB similar pero Rio de Janerio tiene menos congestion. Por lo tanto, no hay una relacion, si es que existe una relacion.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor (1ra Iteración)</b> <a class="tocSkip"></a>
#
# Generaste los tres gráficos solicitados y el boxplot incluye la media, lo cual ayuda a interpretar outliers, aunque convendría mantener una convención de nombres clara en ejes.
#
# Como recomendación para la última gráfica, al mezclar variables con escalas tan distintas el mensaje puede volverse confuso, podrías usar gráficos separados o normalizar los valores. Otra opción sería configurar dos ejes Y distintos, lo cual permita presentar la información de manera más clara. Te comparto una página donde explican como hacer esta configuración: [Enlace](https://www.analyticslane.com/2022/08/04/uso-de-multiples-ejes-en-matplotlib/). La idea es obtener algo como esto:
#
# <img src="https://www.edureka.co/community/?qa=blob&qa_blobid=5104085296578093682" width="300">
# </div>

# %% [markdown]
# ---
#
# ## 🧩Paso 7: Exportar y documentar resultados
#
# En esta etapa final consolidarás todo tu trabajo: guardarás el dataset limpio y crearás un resumen que documente los resultados del proyecto.
#
# ### 7.1 Guardar dataset final
#
# **🎯Objetivo:**
# Generar un CSV limpio, reproducible y con columnas relevantes para análisis posterior.
#
# **Instrucciones**
#
# - Exporta el DataFrame `merged` con el nombre: `ladb_mobility_economy_2024_clean.csv`
# - Usa `index=False` para no incluir el índice.

# %%
# Validación ANTES de exportar
print("=== VALIDACIÓN ANTES DE EXPORTAR ===")
print(f"Forma del dataset: {merged.shape}")
print(f"Columnas: {list(merged.columns)}")
print(f"Valores nulos por columna:")
print(merged.isnull().sum())
print(f"Duplicados: {merged.duplicated().sum()}")

# Exporta el dataset final como CSV
merged.to_csv("ladb_mobility_economy_2024_clean.csv", index=False)
print("\n✅ Dataset exportado exitosamente")

# Validación DESPUÉS de exportar
print("\n=== VALIDACIÓN DESPUÉS DE EXPORTAR ===")
# Leer el archivo recién creado para verificar
import os
file_size = os.path.getsize("ladb_mobility_economy_2024_clean.csv")
print(f"Tamaño del archivo: {file_size:,} bytes")

# Verificar que se puede leer correctamente
test_read = pd.read_csv("ladb_mobility_economy_2024_clean.csv")
print(f"Filas leídas del CSV: {len(test_read)}")
print(f"Columnas leídas del CSV: {len(test_read.columns)}")
print("Primeras 3 filas del archivo exportado:")
print(test_read.head(3))
# Out:
# === VALIDACIÓN ANTES DE EXPORTAR ===
# Forma del dataset: (15, 13)
# Columnas: ['city', 'country', 'year', 'jamsdelay', 'trafficindexlive', 'jamscount', 'minsdelay', 'traveltimeliveper10kmsmins', 'traveltimehistoricper10kmsmins', 'city_gdp_capita', 'unemployment_pct', 'pm2_5', 'population']
# Valores nulos por columna:
# city                              0
# country                           0
# year                              0
# jamsdelay                         0
# trafficindexlive                  0
# jamscount                         0
# minsdelay                         0
# traveltimeliveper10kmsmins        0
# traveltimehistoricper10kmsmins    0
# city_gdp_capita                   0
# unemployment_pct                  0
# pm2_5                             0
# population                        0
# dtype: int64
# Duplicados: 0
#
# ✅ Dataset exportado exitosamente
#
# === VALIDACIÓN DESPUÉS DE EXPORTAR ===
# Tamaño del archivo: 2,560 bytes
# Filas leídas del CSV: 15
# Columnas leídas del CSV: 13
# Primeras 3 filas del archivo exportado:
#              city country  year    jamsdelay  trafficindexlive   jamscount  \
# 0  belo-horizonte     BRA  2024   263.047879         19.428946   68.805422
# 1          bogota     COL  2024  1141.552364         37.614273  230.566550
# 2        brasilia     BRA  2024   101.576326         11.258220   27.280140
#
#    minsdelay  traveltimeliveper10kmsmins  traveltimehistoricper10kmsmins  \
# 0   0.487228                   18.304538                       17.817311
# 1   1.699628                   24.992185                       23.292557
# 2   0.193442                   13.338658                       13.145216
#
#    city_gdp_capita  unemployment_pct  pm2_5  population
# 0          11124.0               9.5   16.8   6100000.0
# 1          11442.0              10.0   17.6  11300000.0
# 2          16251.0               7.8   12.8   4800000.0

# %% [markdown]
# Para poder ver o descargar el archivo generado:
# En el menú lateral que esta a la izquierda, ve hasta la parte de abajo, a la sección de **Exportar dataset** para más información.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor (1ra Iteración)</b> <a class="tocSkip"></a>
#
# La exportación de **merged** a CSV está correcta con `index=False`, pero faltó una validación rápida del archivo generado o del tamaño del dataset para asegurar que se exportó la versión final realmente depurada.
#
# </div>

# %% [markdown]
# ---
#
# ## ✅ Entregables
#
# 1. **Notebook `.ipynb`** con todas las celdas (código + comentarios).
# 2. **CSV final**: `ladb_mobility_economy_2024_clean.csv`.
# 3. **Resumen ejecutivo breve** en Markdown (3–5 párrafos).

# %% [markdown]
# ---
#
# # 🧾 Resumen ejecutivo (plantilla)
#
# > Completa este resumen al finalizar el análisis. Mantén 3–5 párrafos cortos, claros y accionables.
#
# **Contexto & objetivo:**
# - Responde la pregunta central del análisis: ¿qué relación existe entre la movilidad urbana (congestión, tiempos de viaje) y la productividad económica (PIB per cápita)?
# - Explica brevemente las variables clave utilizadas y su relevancia para la toma de decisiones.
#
# **Cobertura de datos:**
# - Especifica los años analizados, número de ciudades y países incluidos.
#
# **Metodología (alto nivel):**
# - Describe los procesos principales: limpieza de datos (formatos, estandarización de columnas).
# - Explica la agregación por ciudad–año y el uso de una unión INNER para integrar tráfico y economía.
# - Menciona las validaciones visuales empleadas (distribuciones, outliers, tendencias generales).
#
# **Hallazgos iniciales:**
# - Resume los patrones más importantes entre índices de tráfico y PIB per cápita.
# - Destaca anomalías u outliers que podrían requerir revisión adicional o un análisis más profundo.
#
# **Recomendaciones**
# Aterriza los hallazgos en acciones: ciudades prioritarias, necesidad de validar fuentes, requerimiento de análisis adicionales, o propuestas de inversión.
#
# - ¿Qué ciudad : Bogotá, Lima o Buenos Aires o alguna otra en particular, muestra la mayor correlación significativa entre altos niveles de congestión vehicular y bajos indicadores de productividad económica, sugiriendo ser una ciudad prioritaria para inversión en infraestructura de transporte?

# %% [markdown]
# Se busca establecer la relación entre movilidad urbana y productividad económica. Para ello
# se utilizaron variables clave, las cuales fueron las de retraso provocadas por gestión vehicular y las del Producto Interno Bruto per cápita, el cual refleja el nivel de productividad económica por habitante.
# El análisis basado en dichas variables, demuestra que no existe una relación clara entre la movilidad urbana (congestión, tiempos de viaje) y la productividad económica (PIB per cápita). Es importante que el banco sepa esto a la hora de considerar dónde realizará la inversión, para que considere otros criterios más fiables en los que basar su inversión.

# %% [markdown]
# Para propositos de este analisis se tomaron en cuenta 7 paises latinoamericanos
# y 15 ciudades repartidas entre dichos paises. Para efectos de las variables arriba mencionadas,
# solo se tomaron en cuenta los valores correspondientes al año 2024.

# %% [markdown]
# Se realizó un proceso de estanzarización de nombres de columnas (todos en minusculas, sin espacios,
# sin signos extraños, etc.) y se corrigieron los tipos de datos asociados a dichas columnas, tales
# como la columna "update_time_utc" que requirió el tipo de dato "datetime" correspondiente al formato de fecha. Esto es muy importante ya que esta columna nos da la fecha y hora de la actualización de tráfico y un parseo incorrecto puede generar información incorrecta, o al menos ruido innecesario.
# Se identificó un gran número de columnas con tipo de dato incorrecto. La mayoría particularmente en Eco tenia columnas de tipo "object" cuando se requerían en tipo "float". Se hizo el cambio correspondiente a "float" dejando solamente "city" y "country" como tipo object, que sirven para este analisis.
# Se realizo extracción y filtrado de datos basados en el año 2024 y se realizaron calculos de promedio
# de trafico por ciudad y se utilizo la unión de dataframes mediante INNER JOIN para poder integrar
# los datos de trafico y economia y asi poder realizar comparaciones entre ambos.
# Se utilizaron metodos de graficacion para poder visualizar la información más relevante de forma
# clara y objetiva: diagramas de caja para poder observar la congestion e identificar valores atipicos;
# histogramas para poder observar la distribución de la economia. Y grafico de barras para poder
# comparar ambas variables e identificar la relación entre ambas.

# %% [markdown]
# Al observar la grafica de comparación de PIB vs congestión se puede ver que no hay una relación
# clara en las variables. Montevideo posee el mayor PIB y su nivel de congestion entre los mas bajos,
# Salvador tiene niveles similares de congestion y su PIB es mucho mas bajo que el de Montevideo.
# Santiago tiene niveles de congestion similares a los de Buenos Aires pero hay una drastica diferencia
# entre sus respectivos PIBs. Los patrones observados indican una falta de relación entre ambos factores.
# Al comparar el caso de Santiago con el de Ciudad de Mexico, se ve claramente que una menor congestión
# no necesariamente conlleva un mejor PIB.
# Por otro lado se han identificado outliers extremos gracias al grafico de diagrama de caja. Teniendo un
# promedio de 629 minutos aprox. hay valores que son mas del doble del promedio. Esto puede estar
# afectando el analisis.

# %% [markdown]
# Debido a la presencia de fuertes outliers identificados, Se sugiere validar las fuentes de los
# datos capturados para poder llevar a cabo un nuevo análisis. Es posible que esto nos permita establecer
# una relación más clara entre congestión y productividad economica.
# La ciudad de Santiago tiene niveles relativamente altos de congestion y el nivel mas bajo de productividad,
# por lo que, si se asume una relacion entre ambos, -insistimos en la ambiguedad de esta relación-
# entonces esta puede ser la mejor ciudad para invertir si existe la convicción de que niveles mas
# bajos de congestion conllevaran una mayor productividad.
# No obstante, insistimos en la revision de las fuentes de datos y la realizacion de un nuevo y más
# profundo analisis.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor (1ra Iteración)</b> <a class="tocSkip"></a>
#
# Tu resumen explica bien el objetivo y comunica la idea principal de que la relación tráfico–productividad no se ve evidente a simple vista, además de reconocer que los outliers pueden influir en la lectura de los resultados.
#
# Hay puntos a ajustar para que el cierre quede más sólido, por ejemplo se menciona la conversión de *year* como fecha cuando el proceso relevante es el parseo de *update_time_utc*, y la conclusión depende casi por completo de inspección visual sin reforzar con una validación sencilla y consistente.
#
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Respuesta del estudiante</b> <a class=“tocSkip”></a>
#
# He corregido los puntos que me indicaron a lo largo del proyecto, y en este ultimo caso tambien
# he tomado en cuenta lo que se menciona respecto al parseo de UTC como un detalle mucho mas relevante
# que el de la columna "year".
#
# No obstante, no logro percibir que es lo que esta mal con mi conclusion. Se indica que esta
# se apoya mucho en la visualizacion de los graficos, pero mi comprension luego de muchas lecciones
# es que esa es la idea. Convertir los datos y el analisis en una representacion visual que demuestre
# lo que se diciendo. Lo que se esta concluyendo es que no hay una relacion clara entre las variables
# y yo uso el grafico y llamo la atencion sobre partes del mismo para poder demostrarlo. Por lo tanto
# no entiendo cual es el problema con mi conclusion y apreciaria mas claridad en la retroalimentacion.
#
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (2da Iteración)</b> <a class=“tocSkip”></a>
#
# Tienes razón en que las visualizaciones son una parte central del análisis, sirven justamente para identificar patrones, comparar casos y comunicar hallazgos de forma clara. El punto de la retroalimentación no es que esté mal usar gráficos para sostener tu conclusión, sino que, en este caso, la afirmación de que “no hay una relación clara” queda apoyada casi únicamente en inspección visual y no en una comprobación adicional, aunque sea muy simple.
#
# Lo que se esperaba para fortalecer el resumen era complementar esa lectura visual con una validación breve y consistente. Por ejemplo, podrías mencionar que, además de observar el gráfico, calculaste una correlación entre congestión y PIB per cápita y que el resultado fue débil o no concluyente. También era importante cuidar el lenguaje de la conclusión, si el análisis muestra ambigüedad y presencia de outliers, entonces conviene evitar frases que suenen demasiado firmes, como señalar una ciudad prioritaria “por correlación significativa”, cuando precisamente no se demostró esa significancia.
#
# En otras palabras, la observación visual está bien y sí aporta valor; lo que faltaba era un pequeño respaldo analítico para que la conclusión no dependiera solo de la interpretación del gráfico. Por eso la sugerencia apuntaba a fortalecer el resumen, no a invalidar tu enfoque.
#
# </div>
